# %%
import glob # đọc đuôi file 
import PIL.Image as Img
from torch.utils.data import Dataset
from torchvision import transforms
import torch

# %%
a = glob.glob("C:\\Users\\User\\Documents\\Works\\PAIL\\Generative-Test\\Data_checktest"+"\\*")

# %%
print(a)
# Out:
# ['C:\\Users\\User\\Documents\\Works\\PAIL\\Generative-Test\\Data_checktest\\00000.png', 'C:\\Users\\User\\Documents\\Works\\PAIL\\Generative-Test\\Data_checktest\\00001.png', 'C:\\Users\\User\\Documents\\Works\\PAIL\\Generative-Test\\Data_checktest\\00002.png', 'C:\\Users\\User\\Documents\\Works\\PAIL\\Generative-Test\\Data_checktest\\00003.png', 'C:\\Users\\User\\Documents\\Works\\PAIL\\Generative-Test\\Data_checktest\\00004.png', 'C:\\Users\\User\\Documents\\Works\\PAIL\\Generative-Test\\Data_checktest\\00005.png', 'C:\\Users\\User\\Documents\\Works\\PAIL\\Generative-Test\\Data_checktest\\00006.png', 'C:\\Users\\User\\Documents\\Works\\PAIL\\Generative-Test\\Data_checktest\\00007.png', 'C:\\Users\\User\\Documents\\Works\\PAIL\\Generative-Test\\Data_checktest\\00008.png', 'C:\\Users\\User\\Documents\\Works\\PAIL\\Generative-Test\\Data_checktest\\00009.png', 'C:\\Users\\User\\Documents\\Works\\PAIL\\Generative-Test\\Data_checktest\\00010.png']

# %%
b = []

# %%
ten = torch.tensor([[[]]])

# %%
print(ten)
# Out:
# tensor([], size=(1, 1, 0))

# %%
for i in a:
    img = Img.open(a[i])
    b.append(img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\User\Documents\Works\PAIL\Generative-Test\test.ipynb Cell 5 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/Works/PAIL/Generative-Test/test.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> for i in a:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/Works/PAIL/Generative-Test/test.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a>     img = Img.open(a[i])
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/Works/PAIL/Generative-Test/test.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a>     b.append(img)
#
# TypeError: list indices must be integers or slices, not str

# %%
print(b[0])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x19002BD8DC0>

# %%
img = Img.open(a[0])
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x1900FBE10F0>
