# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline
from IPython.display import Image

# %%
Image(filename=r".\Garfal.png")

# %%
cb_img = cv2.imread(r".\Garfal.png",0)

# %%
print(cb_img)
# Out:
# [[78 78 78 ... 78 78 78]
#  [78 78 78 ... 78 78 78]
#  [78 78 78 ... 78 78 78]
#  ...
#  [78 78 78 ... 78 78 78]
#  [78 78 78 ... 78 78 78]
#  [78 78 78 ... 78 78 78]]

# %%
from PIL import Image
img = Image.open(r'Garfal.png')
new_img = img.resize((50,50))
new_img.save('Garfal1','png')
print(new_img)
new_img.show()
# Out:
# <PIL.Image.Image image mode=RGB size=50x50 at 0x1E966B5A0D0>

# %%
from IPython.display import Image 
Image(filename=r"Garfal50x50.PNG")
cb_img1 = cv2.imread(r"Garfal50x50.PNG",0)
print(cb_img1)
# Out:
# None
